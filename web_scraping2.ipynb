# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

product_name = []
images = []
descriptions = [] # This is the correct variable name
url = "https://myfrido.com/collections/shoe-inserts"
headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json",
}

r=requests.get(url,headers=headers)
soup=BeautifulSoup(r.text,"lxml")
# print (soup)
name = soup.find_all("p")
for i in name:
   product_name.append(i.text)
   print(f"The productname is here {product_name}")
img=soup.find_all("img")
for j in img:
  j.get("src")
  print(j.get("src"))
    # img=images.append(j.get("src"))
    # print(f"The image  is here {images}")
# for j in descripition:
#    print(j.text)
    # """descriptions.append(i.text)  # Use the correct variable name here

    # print(f"The description  is here {descriptions}")"""
# Out:
# The productname is here ['{"collection":{"id":263604240418,"title":"Shoe Inserts","handle":"shoe-inserts","description":"","published_at":"2021-11-23T22:29:29+05:30","updated_at":"2025-02-20T17:20:12+05:30","image":{"id":1741853983001,"created_at":"2023-08-26T12:51:58+05:30","src":"https:\\/\\/cdn.shopify.com\\/s\\/files\\/1\\/0553\\/0419\\/2034\\/collections\\/SEO_MyFrido_ShoeInserts.png?v=1693034519","alt":null},"products_count":30}}']

# %%
images=[]
url="https://myfrido.com/collections/shoe-inserts"
headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json",
}

r=requests.get(url,headers=headers)
soup=BeautifulSoup(r.content,"lxml")
# print(soup)
imge=soup.find_all('img')
imge
# for i in img:

#     img=images.append(i.get("src"))

# print(f"The images links is here {images}")
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
titles=[]

url = "https://www.wikipedia.org/"
headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json",
}

r= requests.get(url,headers=headers)
print(r)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.content,"lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia</title>
# <meta content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation." name="description"/>
# <script>
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)no-js(\s|$)/, "$1js-enabled$2" );
# </script>
# <meta content="initial-scale=1,user-scalable=yes" name="viewport"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="//creativecommons.org/licenses/by-sa/4.0/" rel="license"/>
# <style>
# ...

# %%
link = soup.find_all("a")
for i in link:
  (titles.append(i.get('href')))

# %%
data = {"link":titles}
pd.DataFrame(data)
# Out:
#                                                   link
# 0                                  //en.wikipedia.org/
# 1                                  //ja.wikipedia.org/
# 2                                  //ru.wikipedia.org/
# 3                                  //de.wikipedia.org/
# 4                                  //es.wikipedia.org/
# ..                                                 ...
# 364                           //www.wikifunctions.org/
# 365                              //meta.wikimedia.org/
# 366    https://creativecommons.org/licenses/by-sa/4.0/
# 367  https://foundation.wikimedia.org/wiki/Special:...
# 368  https://foundation.wikimedia.org/wiki/Special:...
#
# [369 rows x 1 columns]

# %%
img = soup.find_all("img")
img
for k in img:
 img=images.append(k.get("src"))

# %%
print(images)
# Out:
# ['portal/wikipedia.org/assets/img/Wikipedia-logo-v2.png']

# %%
data = {"img":images}
pd.DataFrame(data)
# Out:
#                                                  img
# 0  portal/wikipedia.org/assets/img/Wikipedia-logo...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

Headlines=[]
images=[]
linkss=[]
paragraph=[]

url = "https://www.bbc.com/"
headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json",
}

r= requests.get(url,headers=headers)
soup = BeautifulSoup(r.content,"lxml")
# print(soup.prettify)
link = soup.find_all("a")
for i in link :
  (linkss.append(i.get('href')))

img = soup.find_all("img")
img
for k in img:
 img=images.append(k.get("src"))
#  print(images)
#  data = {"img":images}
#  pd.DataFrame(data)
head = soup.find_all("div",class_ = "sc-8ea7699c-3 dhclWg")

# %%
 data = {"link":linkss}
 pd.DataFrame(data)
# Out:
#                                                   link
# 0                                        #main-content
# 1                                                    /
# 2                                    /watch-live-news/
# 3                                                    /
# 4                                                /news
# ..                                                 ...
# 212                      https://www.bbc.co.uk/contact
# 213             https://www.bbc.com/advertisingcontact
# 214  https://www.bbc.com/usingthebbc/cookies/how-ca...
# 215           https://www.bbc.com/contact-bbc-com-help
# 216  https://www.bbc.co.uk/editorialguidelines/guid...
#
# [217 rows x 1 columns]

# %%
 data = {"img":images}
 pd.DataFrame(data)
# Out:
#                                                   img
# 0                          /bbcx/grey-placeholder.png
# 1   https://ichef.bbci.co.uk/ace/standard/480/cpsp...
# 2                          /bbcx/grey-placeholder.png
# 3   https://ichef.bbci.co.uk/news/480/cpsprodpb/da...
# 4                          /bbcx/grey-placeholder.png
# ..                                                ...
# 69  https://ichef.bbci.co.uk/images/ic/480x270/p0k...
# 70                         /bbcx/grey-placeholder.png
# 71  https://ichef.bbci.co.uk/news/480/cpsprodpb/03...
# 72                         /bbcx/grey-placeholder.png
# 73  https://ichef.bbci.co.uk/images/ic/480x270/p0k...
#
# [74 rows x 1 columns]

# %%
head = soup.find_all("h2",class_ = "sc-8ea7699c-3 dhclWg")
for j in head :
 Headlines.append(j.text)

data={"headlins":Headlines}
pd.DataFrame(data)

# Headlines
# Out:
#                                               headlins
# 0    Russia holds 'the cards' in Ukraine peace talk...
# 1    Trump echoes Russia as he upends US position o...
# 2    Russia holds 'the cards' in Ukraine peace talk...
# 3    Trump echoes Russia as he upends US position o...
# 4          Charges against Liam Payne's friend dropped
# ..                                                 ...
# 121  Japan to increase reliance on nuclear energy i...
# 122          Giada de Laurentiis' family guide to Rome
# 123         Where to get the best gumbo in New Orleans
# 124                Where to see Boston's Black culture
# 125  A Chinese fashion influencer's guide to Hong Kong
#
# [126 rows x 1 columns]

# %%
par = soup.find_all("p",class_ = "sc-b8778340-4 kYtujW")
par
for l in par :
  paragraph.append(l.text)

data={"par":paragraph}
pd.DataFrame(data)
# Out:
#                                                   par
# 0   Ukrainian President Volodymyr Zelensky is set ...
# 1   While the sudden change in US foreign policy i...
# 2   The all-female Forty Elephants lived by their ...
# 3   Some women are concerned about how contracepti...
# 4   The Cessna 172S and a Lancair 360 MK II had tw...
# 5   Steve Brisley reunites with his brother-in-law...
# 6   The comments come as the latest salvo in a pub...
# 7   Real Madrid forward Kylian Mbappe's goal again...
# 8   Humanitarian workers fear the detention of sta...
# 9   In Tulsi, a village in central India, social m...
# 10  The woman, from the state of Georgia, has been...
# 11  The rap mogul denies sex trafficking and racke...
# 12  The search continues for work by artist Henry ...
# 13  Wesley Schultz, half of the rock duo The Lumin...
# 14  A new energy plan cites growing demand from po...
# 15  Angelababy has called Hong Kong home since she...
